# %% [markdown]
# <a href="https://colab.research.google.com/github/andrealvzvz/Analitica-de-Datos/blob/main/Holamundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#comentario de prueba 
#testyFesty
import numpy as np
from matplotlib import pyplot as plt
ys = 200 + np.random.randn(100)
x = np.arange(0, 100, 1)

# %%
#graficamos los arreglos en un plano 2D
plt.plot(x,ys, ".")
plt.fill_between(x, ys, 195, where=(ys > 200), facecolor='r', alpha=0.6)
#titulos
plt.title("Sample Visualization")
plt.xlabel("x", size = 16,)
plt.ylabel("y", size = 16)
plt.show()
